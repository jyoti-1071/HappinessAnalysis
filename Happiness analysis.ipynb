# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1=pd.read_csv("happiness/2015.csv")
df2=pd.read_csv("happiness/2016.csv")
df3=pd.read_csv("happiness/2017.csv")
df4=pd.read_csv("happiness/2018.csv")
df5=pd.read_csv("happiness/2019.csv")

# %%
df1.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204

# %%
df2.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# ...

# %%
df3.head(3)
# Out:
#    Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0   Norway               1            7.537      7.594445     7.479556
# 1  Denmark               2            7.522      7.581728     7.462272
# 2  Iceland               3            7.504      7.622030     7.385970
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715

# %%
df4.head(3)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408

# %%
df5.head(3)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341

# %%
df1.drop(columns=["Standard Error","Region"],inplace=True)

# %%
df1.rename(columns={"Economy (GDP per Capita)":"GDP per capita", "Health (Life Expectancy)":"Healthy life expectancy"},inplace=True)

# %%
# df1.set_index("Country",inplace=True)

# %%
df2.drop(columns=["Lower Confidence Interval","Upper Confidence Interval","Region"],inplace=True)

# %%
df2.rename(columns={"Economy (GDP per Capita)":"GDP per capita", "Health (Life Expectancy)":"Healthy life expectancy"},inplace=True)

# %%
# df2.set_index("Country",inplace=True)

# %%
df3.drop(columns=["Whisker.high","Whisker.low"],inplace=True)

# %%
df3.rename(columns={"Happiness.Rank":"Happiness Rank","Happiness.Score":"Happiness Score",
                    "Economy..GDP.per.Capita.":"GDP per capita",
                   "Health..Life.Expectancy.":"Healthy life expectancy",
                    "Trust..Government.Corruption.":"Trust (Government Corruption)",
                   "Dystopia.Residual":"Dystopia Residual"}
          ,inplace=True)

# %%
# df3.set_index("Country",inplace=True)

# %%
df4.rename(columns={"Overall rank":"Happiness Rank","Country or region":"Country","Score":"Happiness Score",
                   "Social support":"Family","Freedom to make life choices":"Freedom",
                    "Perceptions of corruption":"Trust (Government Corruption)"},inplace=True)

# %%
df4["Dystopia Residual"]=df4["Happiness Score"]-(df4["GDP per capita"]+df4["Family"]+df4["Freedom"]+
                                                 df4["Healthy life expectancy"]+df4["Generosity"]+
                                                 df4["Trust (Government Corruption)"])

# %%
# df4.set_index("Country",inplace=True)

# %%
df5.rename(columns={"Overall rank":"Happiness Rank","Country or region":"Country","Score":"Happiness Score",
                   "Social support":"Family","Freedom to make life choices":"Freedom",
                    "Perceptions of corruption":"Trust (Government Corruption)"},inplace=True)

# %%
df5["Dystopia Residual"]=df5["Happiness Score"]-(df5["GDP per capita"]+df5["Family"]+df5["Freedom"]+
                                                 df5["Healthy life expectancy"]+df5["Generosity"]+
                                                 df5["Trust (Government Corruption)"])

# %%
# df5.set_index("Country",inplace=True)

# %%
df5.head(3)
# Out:
#    Happiness Rank  Country  Happiness Score  GDP per capita  Family  \
# 0               1  Finland            7.769           1.340   1.587
# 1               2  Denmark            7.600           1.383   1.573
# 2               3   Norway            7.554           1.488   1.582
#
#    Healthy life expectancy  Freedom  Generosity  \
# 0                    0.986    0.596       0.153
# 1                    0.996    0.592       0.252
# 2                    1.028    0.603       0.271
#
#    Trust (Government Corruption)  Dystopia Residual
# 0                          0.393              2.714
# 1                          0.410              2.394
# 2                          0.341              2.241

# %%
cnt=np.intersect1d(df1.Country[:10],np.intersect1d(df2.Country[:10],np.intersect1d(df3.Country[:10],np.intersect1d(df4.Country[:10],df5.Country[:10]))))

# %%
cnt
# Out:
# array(['Canada', 'Denmark', 'Finland', 'Iceland', 'Netherlands',
#        'New Zealand', 'Norway', 'Sweden', 'Switzerland'], dtype=object)

# %%
years=["2015","2016","2017","2018","2019"]

# %%
for i in df1["Country"]:
    if i not in list(df2["Country"]):
        print(i)
# Out:
# Oman
# Somaliland region
# Mozambique
# Lesotho
# Swaziland
# Djibouti
# Central African Republic

# %%
df1.set_index("Country",inplace=True)

# %%
df2.set_index("Country",inplace=True)

# %%
df3.set_index("Country",inplace=True)

# %%
df4.set_index("Country",inplace=True)

# %%
df5.set_index("Country",inplace=True)

# %%
df=pd.concat([df1.head(10),df2.head(10),df3.head(10),df4.head(10),df5.head(10)],axis=0,keys=years)
df6=pd.concat([df1,df2,df3,df4,df5],axis=0,keys=years)

# %% [markdown]
# From this data we can observe that Australia has decreasing Happiness score from since 2017

# %%
df.to_csv("happiest_countries.csv")

# %%
da=df6.xs('Australia', level='Country', axis=0)

# %%
da
# Out:
#       Happiness Rank  Happiness Score  GDP per capita    Family  \
# 2015              10            7.284        1.333580  1.309230
# 2016               9            7.313        1.444430  1.104760
# 2017              10            7.284        1.484415  1.510042
# 2018              10            7.272        1.340000  1.573000
# 2019              11            7.228        1.372000  1.548000
#
#       Healthy life expectancy   Freedom  Trust (Government Corruption)  \
# 2015                 0.931560  0.651240                       0.356370
# 2016                 0.851200  0.568370                       0.323310
# 2017                 0.843887  0.601607                       0.301184
# 2018                 0.910000  0.647000                       0.302000
# 2019                 1.036000  0.557000                       0.290000
#
#       Generosity  Dystopia Residual
# 2015    0.435620           2.266460
# 2016    0.474070           2.546500
# 2017    0.477699           2.065211
# ...

# %%
da.index.name="Years"
da
# Out:
#        Happiness Rank  Happiness Score  GDP per capita    Family  \
# Years
# 2015               10            7.284        1.333580  1.309230
# 2016                9            7.313        1.444430  1.104760
# 2017               10            7.284        1.484415  1.510042
# 2018               10            7.272        1.340000  1.573000
# 2019               11            7.228        1.372000  1.548000
#
#        Healthy life expectancy   Freedom  Trust (Government Corruption)  \
# Years
# 2015                  0.931560  0.651240                       0.356370
# 2016                  0.851200  0.568370                       0.323310
# 2017                  0.843887  0.601607                       0.301184
# 2018                  0.910000  0.647000                       0.302000
# 2019                  1.036000  0.557000                       0.290000
#
#        Generosity  Dystopia Residual
# Years
# 2015     0.435620           2.266460
# 2016     0.474070           2.546500
# ...

# %%
da.iloc[:,2:].plot(legend=True,figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Years'>

# %% [markdown]
# Frome this graph we can see that out of 7 features , 4 features reduses simultenously and thus its happiness score decreases

# %%
df6.reset_index(inplace=True)

# %%
df6.rename(columns={"level_0":"Years"},inplace=True)

# %%
df6.set_index("Years")
# Out:
#                         Country  Happiness Rank  Happiness Score  \
# Years
# 2015                Switzerland               1            7.587
# 2015                    Iceland               2            7.561
# 2015                    Denmark               3            7.527
# 2015                     Norway               4            7.522
# 2015                     Canada               5            7.427
# ...                         ...             ...              ...
# 2019                     Rwanda             152            3.334
# 2019                   Tanzania             153            3.231
# 2019                Afghanistan             154            3.203
# 2019   Central African Republic             155            3.083
# 2019                South Sudan             156            2.853
#
#        GDP per capita   Family  Healthy life expectancy  Freedom  \
# Years
# 2015          1.39651  1.34951                  0.94143  0.66557
# ...

# %%
sns.jointplot(x="Happiness Score",y="Trust (Government Corruption)",data=df,kind="hex")

# %% [markdown]
# Frome this graph we can see that out of 7 features , 4 features reduses simultenously and thus its happiness score decreases

# %%
#lets look at relation between GDP  and Happiness score:
sns.regplot(data=df,x=df.iloc[:,1],y=df.iloc[:,2])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='GDP per capita'>

# %%
sns.regplot(data=df,x=df.iloc[:,3],y=df.iloc[:,1])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Happiness Score'>

# %%
sns.regplot(data=df,x=df.iloc[:,4],y=df.iloc[:,1])
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='Happiness Score'>

# %%
sns.regplot(data=df,x=df.iloc[:,5],y=df.iloc[:,1])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Happiness Score'>

# %%
sns.regplot(data=df,x=df.iloc[:,6],y=df.iloc[:,1])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %% [markdown]
# From all this regression plots we get that Freedom,faimly and Gdp are directly related to a countries happiness scores

# %%
import cufflinks as cf
  
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df6
# Out:
#     Years                   Country  Happiness Rank  Happiness Score  \
# 0    2015               Switzerland               1            7.587
# 1    2015                   Iceland               2            7.561
# 2    2015                   Denmark               3            7.527
# 3    2015                    Norway               4            7.522
# 4    2015                    Canada               5            7.427
# ..    ...                       ...             ...              ...
# 777  2019                    Rwanda             152            3.334
# 778  2019                  Tanzania             153            3.231
# 779  2019               Afghanistan             154            3.203
# 780  2019  Central African Republic             155            3.083
# 781  2019               South Sudan             156            2.853
#
#      GDP per capita   Family  Healthy life expectancy  Freedom  \
# 0           1.39651  1.34951                  0.94143  0.66557
# ...

# %%
df8=df6.set_index("Years")
df8
# Out:
#                         Country  Happiness Rank  Happiness Score  \
# Years
# 2015                Switzerland               1            7.587
# 2015                    Iceland               2            7.561
# 2015                    Denmark               3            7.527
# 2015                     Norway               4            7.522
# 2015                     Canada               5            7.427
# ...                         ...             ...              ...
# 2019                     Rwanda             152            3.334
# 2019                   Tanzania             153            3.231
# 2019                Afghanistan             154            3.203
# 2019   Central African Republic             155            3.083
# 2019                South Sudan             156            2.853
#
#        GDP per capita   Family  Healthy life expectancy  Freedom  \
# Years
# 2015          1.39651  1.34951                  0.94143  0.66557
# ...

# %%
df.rename(columns={"level_0":"Years"},inplace=True)

# %%
df.drop(["Happiness Rank","Happiness Score"],axis=1).iplot()
# Out:
# <div>                            <div id="49cf933f-cb4f-4023-825b-e9e30e1977f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df6.set_index("Years")
# Out:
#                         Country  Happiness Rank  Happiness Score  \
# Years
# 2015                Switzerland               1            7.587
# 2015                    Iceland               2            7.561
# 2015                    Denmark               3            7.527
# 2015                     Norway               4            7.522
# 2015                     Canada               5            7.427
# ...                         ...             ...              ...
# 2019                     Rwanda             152            3.334
# 2019                   Tanzania             153            3.231
# 2019                Afghanistan             154            3.203
# 2019   Central African Republic             155            3.083
# 2019                South Sudan             156            2.853
#
#        GDP per capita   Family  Healthy life expectancy  Freedom  \
# Years
# 2015          1.39651  1.34951                  0.94143  0.66557
# ...

# %%
df6.drop(["Happiness Rank","Happiness Score"],axis=1).iplot(kind='box')
# Out:
# <div>                            <div id="e80dee4d-574a-437e-bbc9-1e11943e0fc9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df7=df6.pivot_table(index="Years",values=df6.iloc[:,1:],aggfunc='mean')
df7
# Out:
#        Dystopia Residual    Family   Freedom  GDP per capita  Generosity  \
# Years
# 2015            2.098977  0.991046  0.428615        0.846137    0.237296
# 2016            2.325807  0.793621  0.370994        0.953880    0.242635
# 2017            1.850238  1.188898  0.408786        0.984718    0.246883
# 2018            1.921703  1.213237  0.454506        0.891449    0.181006
# 2019            1.879872  1.208814  0.392571        0.905147    0.184846
#
#        Happiness Rank  Happiness Score  Healthy life expectancy  \
# Years
# 2015        79.493671         5.375734                 0.630259
# 2016        78.980892         5.382185                 0.557619
# 2017        78.000000         5.354019                 0.551341
# 2018        78.500000         5.375917                 0.597346
# 2019        78.500000         5.407096                 0.725244
#
#        Trust (Government Corruption)
# Years
# 2015                        0.143422
# 2016                        0.137624
# ...

# %%
#This plot will show the agerage of all features wrt Year
df7.drop(["Happiness Rank","Happiness Score"],axis=1).iplot()
# Out:
# <div>                            <div id="eaeaa509-5b43-428c-a50e-d95e2213eb4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.jointplot(x="Happiness Score",y="Trust (Government Corruption)",data=df,kind="hex")
